# %% [markdown]
# Splines delimit the pedestrian ID and the number of control points:
#
# ```
# x y frame_number gaze_direction   \
# x y frame_number gaze_direction    \
# ....                                >>> N control points
# x y frame_number gaze_direction    /
# x y frame_number gaze_direction   /
# ```
#
#
# We want to format the data [frame_number, pedestrian_id, x, y]

# %% [markdown]
# **Example of raw data format**
#
# ```
# 204 - the number of splines
# 11 - Num of control points
# 358.000000 -66.000000 6 87.455200 - (2D point, m_id)
# ...
# 11 - Num of control points
# 358.000000 -44.000000 12 89.041168 - (2D point, m_id)
# 311.000000 -45.000000 40 81.634125 - (2D point, m_id)
#
# ```
#
# - The first line is the number of splines, i.e. the number of pedestrians throughout the video
# - Each spline contains the number of observations of a specific pedestrian
# - Observations are a sequence of control points (x, y, frame_number, gaze_direction)

# %%
import os
import math 
import cv2
import numpy as np
from numpy import savetxt
from scipy import interpolate
from operator import itemgetter

# %%
output_dir = 'processed_data'
data_dir = 'UCY_dataset'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
video_path = f'{data_dir}/crowds_zara02.avi'  # add video path here

cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error: Could not open video.")
else:
    _, frame = cap.read()
    height = int(frame.shape[0])
    width = int(frame.shape[1])


def coordinate_transformation(x_c, y_c, width, height):
    """
    Transforms center coordinates into cv coordinates
    """
    cx = width // 2
    cy = height // 2
    x_cv = x_c + cx
    y_cv = -y_c + cy
    return [x_cv, y_cv]

# %%
filename = f'{data_dir}/raw_zara02.txt' # add raw UCY data path here

file = open(filename, 'r')
# number - 
num_pedestrians = int(file.readline().split(' - ')[0])
num_observations = len(file.readlines()) - num_pedestrians

# [frame, pedestrian, x, y]
data = np.zeros((num_observations, 4))

file = open(filename, 'r')
file.readline()
row_count = 0
for i in range(num_pedestrians):

    num_control_points_i = int(file.readline().split(' - ')[0])
    
    for j in range(num_control_points_i):
        points = file.readline().split(' ')
        data[row_count, 0:4] = [int(points[2]), i ] + coordinate_transformation(float(points[0]), float(points[1]), width, height)#float(points[0]), float(points[1])]
        row_count += 1
        

sorted_indices = np.argsort(data[:,0]) 
sorted_data = data[sorted_indices]

savetxt(f'{output_dir}/Data_formated_crowds_zara02.csv', sorted_data, delimiter=',')

# %% [markdown]
# - Following code was taken from https://github.com/Habiba-Amroune/ETH-UCY-Preprocessing

# %%
data_to_interpolate = np.zeros((len(sorted_data), 4), dtype=float)
for i in range(0, len(sorted_data)):
    data_to_interpolate[i, 0] = sorted_data[i, 0]
    data_to_interpolate[i, 1] = sorted_data[i, 1]
    data_to_interpolate[i, 2] = sorted_data[i, 2]
    data_to_interpolate[i, 3] = sorted_data[i, 3]

interpolated_data = np.empty((0, 4), dtype=float)
t = 0
for i in range(1, int(np.max(data_to_interpolate[:, 1])+1)):
    mask = data_to_interpolate[:, 1] == i
    # list of frames where the pedestrian 'i' appeard
    traj_of_ped_i = data_to_interpolate[mask, :]
    if (traj_of_ped_i.size == 0):
        print('-----------------------------------------------------')
        print('this PedID does''t exist in the data', i)
        x = x+1
        t = t+1
    else:
        # the first appearance of the pedestrian 'i'
        x = int(traj_of_ped_i[0, 0])
        # the last appearance of the pedestrian 'i'
        y = int(traj_of_ped_i[-1, 0])

        if ((x % 10) != 0):  # testing on the first frame
            if ((x % 10) < 5):
                x = int(traj_of_ped_i[0, 0]) - (x % 10)
            else:
                x = (int(traj_of_ped_i[0, 0]) - (x % 10))+10

        if ((y % 10) != 0):  # testing on the last frame
            if ((y % 10) < 5):
                y = int(traj_of_ped_i[-1, 0]) - (y % 10)
            else:
                y = (int(traj_of_ped_i[-1, 0]) - (y % 10))+10

        while x < y:  # until last appearance of the pedestrian 'i'
            for j in range(0, traj_of_ped_i.shape[0]):
                z = np.where(traj_of_ped_i[:, 0] == x)
                # if the frame exist copy the values of the positions
                if np.squeeze(traj_of_ped_i[z, 0]) == x:
                    exist_frame = traj_of_ped_i[z, :]
                    interpolated_data = np.append(
                        interpolated_data, exist_frame[0, :, :], axis=0)
                    x = x+1
                else:                                # else: interpolate using scipy.interpolate.interp1d
                    f = interpolate.interp1d(traj_of_ped_i[:, 0], [
                                             traj_of_ped_i[:, 2], traj_of_ped_i[:, 3]], fill_value="extrapolate", bounds_error=False)
                    inter = f(x)
                    interpolated_data = np.append(interpolated_data, np.array(
                        [[int(x), int(i), float(inter[0]), float(inter[1])]]), axis=0)
                    x = x+1
                if x == y+1:
                    break

    percentage = i/(int(np.max(data_to_interpolate[:, 1])+1))*100
    percentage = "{:.2f}".format(percentage)
    print('interpolation percentage ', percentage, '%')
    print('-----------------------------------------------------')

print('Number of missing pedestrians is: ', t)
print('-----------------------------------------------------')


interpolated_data = interpolated_data[np.argsort(interpolated_data[:, 0])]
savetxt(f'{output_dir}/interpolated_data_crowds_zara02.csv',
        interpolated_data, delimiter=',')
# Out:
# /tmp/ipykernel_39810/3120184467.py:41: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if np.squeeze(traj_of_ped_i[z, 0]) == x:
# interpolation percentage  0.49 %
# -----------------------------------------------------
# interpolation percentage  0.98 %
# -----------------------------------------------------
# interpolation percentage  1.47 %
# -----------------------------------------------------
# interpolation percentage  1.96 %
# -----------------------------------------------------
# interpolation percentage  2.45 %
# -----------------------------------------------------
# interpolation percentage  2.94 %
# -----------------------------------------------------
# interpolation percentage  3.43 %
# -----------------------------------------------------
# interpolation percentage  3.92 %
# -----------------------------------------------------
# interpolation percentage  4.41 %
# -----------------------------------------------------
# interpolation percentage  4.90 %
# -----------------------------------------------------
# interpolation percentage  5.39 %
# -----------------------------------------------------
# interpolation percentage  5.88 %
# -----------------------------------------------------
# interpolation percentage  6.37 %
# -----------------------------------------------------
# interpolation percentage  6.86 %
# -----------------------------------------------------
# interpolation percentage  7.35 %
# -----------------------------------------------------
# interpolation percentage  7.84 %
# -----------------------------------------------------
# interpolation percentage  8.33 %
# -----------------------------------------------------
# interpolation percentage  8.82 %
# -----------------------------------------------------
# interpolation percentage  9.31 %
# -----------------------------------------------------
# interpolation percentage  9.80 %
# -----------------------------------------------------
# interpolation percentage  10.29 %
# -----------------------------------------------------
# interpolation percentage  10.78 %
# -----------------------------------------------------
# interpolation percentage  11.27 %
# -----------------------------------------------------
# interpolation percentage  11.76 %
# -----------------------------------------------------
# interpolation percentage  12.25 %
# -----------------------------------------------------
# interpolation percentage  12.75 %
# -----------------------------------------------------
# interpolation percentage  13.24 %
# -----------------------------------------------------
# interpolation percentage  13.73 %
# -----------------------------------------------------
# interpolation percentage  14.22 %
# -----------------------------------------------------
# interpolation percentage  14.71 %
# -----------------------------------------------------
# interpolation percentage  15.20 %
# -----------------------------------------------------
# interpolation percentage  15.69 %
# -----------------------------------------------------
# interpolation percentage  16.18 %
# -----------------------------------------------------
# interpolation percentage  16.67 %
# -----------------------------------------------------
# interpolation percentage  17.16 %
# -----------------------------------------------------
# interpolation percentage  17.65 %
# -----------------------------------------------------
# interpolation percentage  18.14 %
# -----------------------------------------------------
# interpolation percentage  18.63 %
# -----------------------------------------------------
# interpolation percentage  19.12 %
# -----------------------------------------------------
# interpolation percentage  19.61 %
# -----------------------------------------------------
# interpolation percentage  20.10 %
# -----------------------------------------------------
# interpolation percentage  20.59 %
# -----------------------------------------------------
# interpolation percentage  21.08 %
# -----------------------------------------------------
# interpolation percentage  21.57 %
# -----------------------------------------------------
# interpolation percentage  22.06 %
# -----------------------------------------------------
# interpolation percentage  22.55 %
# -----------------------------------------------------
# interpolation percentage  23.04 %
# -----------------------------------------------------
# interpolation percentage  23.53 %
# -----------------------------------------------------
# interpolation percentage  24.02 %
# -----------------------------------------------------
# interpolation percentage  24.51 %
# -----------------------------------------------------
# interpolation percentage  25.00 %
# -----------------------------------------------------
# interpolation percentage  25.49 %
# -----------------------------------------------------
# interpolation percentage  25.98 %
# -----------------------------------------------------
# interpolation percentage  26.47 %
# -----------------------------------------------------
# interpolation percentage  26.96 %
# -----------------------------------------------------
# interpolation percentage  27.45 %
# -----------------------------------------------------
# interpolation percentage  27.94 %
# -----------------------------------------------------
# interpolation percentage  28.43 %
# -----------------------------------------------------
# interpolation percentage  28.92 %
# -----------------------------------------------------
# interpolation percentage  29.41 %
# -----------------------------------------------------
# interpolation percentage  29.90 %
# -----------------------------------------------------
# interpolation percentage  30.39 %
# -----------------------------------------------------
# interpolation percentage  30.88 %
# -----------------------------------------------------
# interpolation percentage  31.37 %
# -----------------------------------------------------
# interpolation percentage  31.86 %
# -----------------------------------------------------
# interpolation percentage  32.35 %
# -----------------------------------------------------
# interpolation percentage  32.84 %
# -----------------------------------------------------
# interpolation percentage  33.33 %
# -----------------------------------------------------
# interpolation percentage  33.82 %
# -----------------------------------------------------
# interpolation percentage  34.31 %
# -----------------------------------------------------
# interpolation percentage  34.80 %
# -----------------------------------------------------
# interpolation percentage  35.29 %
# -----------------------------------------------------
# interpolation percentage  35.78 %
# -----------------------------------------------------
# interpolation percentage  36.27 %
# -----------------------------------------------------
# interpolation percentage  36.76 %
# -----------------------------------------------------
# interpolation percentage  37.25 %
# -----------------------------------------------------
# interpolation percentage  37.75 %
# -----------------------------------------------------
# interpolation percentage  38.24 %
# -----------------------------------------------------
# interpolation percentage  38.73 %
# -----------------------------------------------------
# interpolation percentage  39.22 %
# -----------------------------------------------------
# interpolation percentage  39.71 %
# -----------------------------------------------------
# interpolation percentage  40.20 %
# -----------------------------------------------------
# interpolation percentage  40.69 %
# -----------------------------------------------------
# interpolation percentage  41.18 %
# -----------------------------------------------------
# interpolation percentage  41.67 %
# -----------------------------------------------------
# interpolation percentage  42.16 %
# -----------------------------------------------------
# interpolation percentage  42.65 %
# -----------------------------------------------------
# interpolation percentage  43.14 %
# -----------------------------------------------------
# interpolation percentage  43.63 %
# -----------------------------------------------------
# interpolation percentage  44.12 %
# -----------------------------------------------------
# interpolation percentage  44.61 %
# -----------------------------------------------------
# interpolation percentage  45.10 %
# -----------------------------------------------------
# interpolation percentage  45.59 %
# -----------------------------------------------------
# interpolation percentage  46.08 %
# -----------------------------------------------------
# interpolation percentage  46.57 %
# -----------------------------------------------------
# interpolation percentage  47.06 %
# -----------------------------------------------------
# interpolation percentage  47.55 %
# -----------------------------------------------------
# interpolation percentage  48.04 %
# -----------------------------------------------------
# interpolation percentage  48.53 %
# -----------------------------------------------------
# interpolation percentage  49.02 %
# -----------------------------------------------------
# interpolation percentage  49.51 %
# -----------------------------------------------------
# interpolation percentage  50.00 %
# -----------------------------------------------------
# interpolation percentage  50.49 %
# -----------------------------------------------------
# interpolation percentage  50.98 %
# -----------------------------------------------------
# interpolation percentage  51.47 %
# -----------------------------------------------------
# interpolation percentage  51.96 %
# -----------------------------------------------------
# interpolation percentage  52.45 %
# -----------------------------------------------------
# interpolation percentage  52.94 %
# -----------------------------------------------------
# interpolation percentage  53.43 %
# -----------------------------------------------------
# interpolation percentage  53.92 %
# -----------------------------------------------------
# interpolation percentage  54.41 %
# -----------------------------------------------------
# interpolation percentage  54.90 %
# -----------------------------------------------------
# interpolation percentage  55.39 %
# -----------------------------------------------------
# interpolation percentage  55.88 %
# -----------------------------------------------------
# interpolation percentage  56.37 %
# -----------------------------------------------------
# interpolation percentage  56.86 %
# -----------------------------------------------------
# interpolation percentage  57.35 %
# -----------------------------------------------------
# interpolation percentage  57.84 %
# -----------------------------------------------------
# interpolation percentage  58.33 %
# -----------------------------------------------------
# interpolation percentage  58.82 %
# -----------------------------------------------------
# interpolation percentage  59.31 %
# -----------------------------------------------------
# interpolation percentage  59.80 %
# -----------------------------------------------------
# interpolation percentage  60.29 %
# -----------------------------------------------------
# interpolation percentage  60.78 %
# -----------------------------------------------------
# interpolation percentage  61.27 %
# -----------------------------------------------------
# interpolation percentage  61.76 %
# -----------------------------------------------------
# interpolation percentage  62.25 %
# -----------------------------------------------------
# interpolation percentage  62.75 %
# -----------------------------------------------------
# interpolation percentage  63.24 %
# -----------------------------------------------------
# interpolation percentage  63.73 %
# -----------------------------------------------------
# interpolation percentage  64.22 %
# -----------------------------------------------------
# interpolation percentage  64.71 %
# -----------------------------------------------------
# interpolation percentage  65.20 %
# -----------------------------------------------------
# interpolation percentage  65.69 %
# -----------------------------------------------------
# interpolation percentage  66.18 %
# -----------------------------------------------------
# interpolation percentage  66.67 %
# -----------------------------------------------------
# interpolation percentage  67.16 %
# -----------------------------------------------------
# interpolation percentage  67.65 %
# -----------------------------------------------------
# interpolation percentage  68.14 %
# -----------------------------------------------------
# interpolation percentage  68.63 %
# -----------------------------------------------------
# interpolation percentage  69.12 %
# -----------------------------------------------------
# interpolation percentage  69.61 %
# -----------------------------------------------------
# interpolation percentage  70.10 %
# -----------------------------------------------------
# interpolation percentage  70.59 %
# -----------------------------------------------------
# interpolation percentage  71.08 %
# -----------------------------------------------------
# interpolation percentage  71.57 %
# -----------------------------------------------------
# interpolation percentage  72.06 %
# -----------------------------------------------------
# interpolation percentage  72.55 %
# -----------------------------------------------------
# interpolation percentage  73.04 %
# -----------------------------------------------------
# interpolation percentage  73.53 %
# -----------------------------------------------------
# interpolation percentage  74.02 %
# -----------------------------------------------------
# interpolation percentage  74.51 %
# -----------------------------------------------------
# interpolation percentage  75.00 %
# -----------------------------------------------------
# interpolation percentage  75.49 %
# -----------------------------------------------------
# interpolation percentage  75.98 %
# -----------------------------------------------------
# interpolation percentage  76.47 %
# -----------------------------------------------------
# interpolation percentage  76.96 %
# -----------------------------------------------------
# interpolation percentage  77.45 %
# -----------------------------------------------------
# interpolation percentage  77.94 %
# -----------------------------------------------------
# interpolation percentage  78.43 %
# -----------------------------------------------------
# interpolation percentage  78.92 %
# -----------------------------------------------------
# interpolation percentage  79.41 %
# -----------------------------------------------------
# interpolation percentage  79.90 %
# -----------------------------------------------------
# interpolation percentage  80.39 %
# -----------------------------------------------------
# interpolation percentage  80.88 %
# -----------------------------------------------------
# interpolation percentage  81.37 %
# -----------------------------------------------------
# interpolation percentage  81.86 %
# -----------------------------------------------------
# interpolation percentage  82.35 %
# -----------------------------------------------------
# interpolation percentage  82.84 %
# -----------------------------------------------------
# interpolation percentage  83.33 %
# -----------------------------------------------------
# interpolation percentage  83.82 %
# -----------------------------------------------------
# interpolation percentage  84.31 %
# -----------------------------------------------------
# interpolation percentage  84.80 %
# -----------------------------------------------------
# interpolation percentage  85.29 %
# -----------------------------------------------------
# interpolation percentage  85.78 %
# -----------------------------------------------------
# interpolation percentage  86.27 %
# -----------------------------------------------------
# interpolation percentage  86.76 %
# -----------------------------------------------------
# interpolation percentage  87.25 %
# -----------------------------------------------------
# interpolation percentage  87.75 %
# -----------------------------------------------------
# interpolation percentage  88.24 %
# -----------------------------------------------------
# interpolation percentage  88.73 %
# -----------------------------------------------------
# interpolation percentage  89.22 %
# -----------------------------------------------------
# interpolation percentage  89.71 %
# -----------------------------------------------------
# interpolation percentage  90.20 %
# -----------------------------------------------------
# interpolation percentage  90.69 %
# -----------------------------------------------------
# interpolation percentage  91.18 %
# -----------------------------------------------------
# interpolation percentage  91.67 %
# -----------------------------------------------------
# interpolation percentage  92.16 %
# -----------------------------------------------------
# interpolation percentage  92.65 %
# -----------------------------------------------------
# interpolation percentage  93.14 %
# -----------------------------------------------------
# interpolation percentage  93.63 %
# -----------------------------------------------------
# interpolation percentage  94.12 %
# -----------------------------------------------------
# interpolation percentage  94.61 %
# -----------------------------------------------------
# interpolation percentage  95.10 %
# -----------------------------------------------------
# interpolation percentage  95.59 %
# -----------------------------------------------------
# interpolation percentage  96.08 %
# -----------------------------------------------------
# interpolation percentage  96.57 %
# -----------------------------------------------------
# interpolation percentage  97.06 %
# -----------------------------------------------------
# interpolation percentage  97.55 %
# -----------------------------------------------------
# interpolation percentage  98.04 %
# -----------------------------------------------------
# interpolation percentage  98.53 %
# -----------------------------------------------------
# interpolation percentage  99.02 %
# -----------------------------------------------------
# interpolation percentage  99.51 %
# -----------------------------------------------------
# Number of missing pedestrians is:  0
# -----------------------------------------------------

# %%
def frames_10(inter_data):
    frames = inter_data[:, 0]
    frames = sorted(frames)
    frames = np.unique(frames)
    final_data = []
    for i in range(0, len(frames)):
        id = frames[i]
        if (((id % 10) == 0) or (id == 0)):
            frm = inter_data[inter_data[:, 0] == id, :]
            final_data.extend(frm)
    final_data = np.unique(final_data, axis=0)
    return final_data


Final_data = frames_10(interpolated_data)
savetxt(f'{output_dir}/Final_data_crowds_zara02.csv', Final_data, delimiter=',')
